# %% [markdown]
# # Force align ground truth transcript to speech file with CTC segmentation algorithm for 1 file

# %% [markdown]
# ## Basic execution environment setup

# %%
import os
import torch
import IPython
import torchaudio
import matplotlib
from dataclasses import dataclass
import matplotlib.pyplot as plt
from Tools import forced_alignment_utils

torch.random.manual_seed(0)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %matplotlib inline
matplotlib.rcParams["figure.figsize"] = [16.0, 4.8]

# %% [markdown]
# ## Choose ASR model to use

# %%
# model to use
# bundle = torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H
bundle = torchaudio.pipelines.WAV2VEC2_ASR_LARGE_LV60K_960H

# %% [markdown]
# ## Specify output folder for results

# %%
# folder for saving output wavefiles (and manually plots if needed)
new_dir = "WAV2VEC2_ASR_LARGE_LV60K_960H"
new_dir = os.path.join("/workspace/projects/Alignment/wav2vec2_alignment/single_audio_outputs/forced_aligning", new_dir)
if not os.path.exists(new_dir): os.makedirs(new_dir, exist_ok=True)

# %% [markdown]
# ## Specify path to <audio, gt_transcript> files

# %%
speech_file = r"/workspace/datasets/myst_test/myst_999465_2009-17-12_00-00-00_MS_4.2_024.wav"
transcript_path = r"/workspace/datasets/myst_test/myst_999465_2009-17-12_00-00-00_MS_4.2_024.txt"

# preprocess transcript file
with open(transcript_path, mode="r", encoding="utf-8") as f:
    transcript = f.read().upper().replace(" ", "|")

# %%
# generate the label class probability of each audio frame using wav2vec2

model = bundle.get_model().to(device)
labels = bundle.get_labels()
with torch.inference_mode():
    waveform, _ = torchaudio.load(speech_file)
    emissions, _ = model(waveform.to(device))
    emissions = torch.log_softmax(emissions, dim=-1)

# probability of vocab labels at each time step
emission = emissions[0].cpu().detach()

# %%
print(f"Known vocab: {labels}")
plt.imshow(emission.T)
plt.colorbar()
plt.title("Frame-wise class probability")
plt.xlabel("Time (frames)")
plt.ylabel("Labels from wav2vec2 vocabulary")
plt.show()
# Out:
# Known vocab: ('-', '|', 'E', 'T', 'A', 'O', 'N', 'I', 'H', 'S', 'R', 'D', 'L', 'U', 'M', 'W', 'C', 'F', 'G', 'Y', 'P', 'B', 'V', 'K', "'", 'X', 'J', 'Q', 'Z')

# %%
dictionary = {c: i for i, c in enumerate(labels)}

tokens = [dictionary[c] for c in transcript]
print(list(zip(transcript, tokens)))

trellis = forced_alignment_utils.get_trellis(emission, tokens)
# Out:
# [('T', 3), ('E', 2), ('M', 14), ('P', 20), ('E', 2), ('R', 10), ('A', 4), ('T', 3), ('U', 13), ('R', 10), ('E', 2), ('|', 1), ('W', 15), ('E', 2), ('N', 6), ('T', 3), ('|', 1), ('D', 11), ('O', 5), ('W', 15), ('N', 6), ('|', 1), ('U', 13), ('M', 14), ('|', 1), ('F', 17), ('I', 7), ('F', 17), ('T', 3), ('E', 2), ('E', 2), ('N', 6), ('|', 1), ('D', 11), ('E', 2), ('G', 18), ('R', 10), ('E', 2), ('E', 2), ('S', 9), ('|', 1), ('C', 16), ('A', 4), ('U', 13), ('S', 9), ('E', 2), ('|', 1), ('F', 17), ('R', 10), ('O', 5), ('M', 14), ('|', 1), ('S', 9), ('T', 3), ('A', 4), ('R', 10), ('T', 3), ('|', 1), ('I', 7), ('T', 3), ('|', 1), ('W', 15), ('A', 4), ('S', 9), ('|', 1), ('A', 4), ('T', 3), ('|', 1), ('T', 3), ('W', 15), ('E', 2), ('N', 6), ('T', 3), ('Y', 19), ('|', 1), ('A', 4), ('N', 6), ('D', 11), ('|', 1), ('A', 4), ('T', 3), ('|', 1), ('F', 17), ('I', 7), ('N', 6), ('I', 7), ('S', 9), ('H', 8), ('|', 1), ('I', 7), ('T', 3), ('|', 1), ('E', 2), ('N', 6), ('D', 11), ('E', 2), ('D', 11), ('|', 1), ('A', 4), ('T', 3), ('|', 1), ('F', 17), ('I', 7), ('V', 22), ('E', 2), ('|', 1), ('D', 11), ('E', 2), ('G', 18), ('R', 10), ('E', 2), ('E', 2)]

# %%
plt.imshow(trellis[1:, 1:].T, origin="lower")
plt.annotate("- Inf", (trellis.size(1) / 5, trellis.size(1) / 1.5))
plt.colorbar()
plt.title("trellis matrix, colour represents confidence score")
plt.xlabel("frame")
plt.ylabel("char index in ground truth transcript")
plt.show()

# %%
path = forced_alignment_utils.backtrack(trellis, emission, tokens)
for p in path:
    print(p)
# Out:
# Point(token_index=0, time_index=2, score=0.9737076163291931)
# Point(token_index=0, time_index=3, score=0.9998570680618286)
# Point(token_index=0, time_index=4, score=0.9998476505279541)
# Point(token_index=0, time_index=5, score=0.9998615980148315)
# Point(token_index=1, time_index=6, score=0.9927003979682922)
# Point(token_index=1, time_index=7, score=0.9998242259025574)
# Point(token_index=2, time_index=8, score=0.9923292994499207)
# Point(token_index=2, time_index=9, score=0.9998602867126465)
# Point(token_index=3, time_index=10, score=0.9963849782943726)
# Point(token_index=3, time_index=11, score=0.9998251795768738)
# Point(token_index=4, time_index=12, score=0.9986553192138672)
# Point(token_index=4, time_index=13, score=0.9998464584350586)
# Point(token_index=5, time_index=14, score=0.9962980151176453)
# Point(token_index=5, time_index=15, score=0.9936172962188721)
# Point(token_index=5, time_index=16, score=0.9998512268066406)
# Point(token_index=6, time_index=17, score=0.9971719980239868)
# Point(token_index=6, time_index=18, score=0.9998394250869751)
# Point(token_index=7, time_index=19, score=0.9992458820343018)
# Point(token_index=7, time_index=20, score=0.9998623132705688)
# Point(token_index=7, time_index=21, score=0.9998475313186646)
# Point(token_index=7, time_index=22, score=0.9998506307601929)
# Point(token_index=7, time_index=23, score=0.9998588562011719)
# Point(token_index=8, time_index=24, score=0.9968200922012329)
# Point(token_index=8, time_index=25, score=0.4418695867061615)
# Point(token_index=9, time_index=26, score=0.9980177879333496)
# Point(token_index=10, time_index=27, score=0.9983181953430176)
# Point(token_index=10, time_index=28, score=0.979905903339386)
# Point(token_index=10, time_index=29, score=0.002235207473859191)
# Point(token_index=11, time_index=30, score=0.9975535273551941)
# Point(token_index=11, time_index=31, score=0.5407687425613403)
# Point(token_index=11, time_index=32, score=0.9998120665550232)
# Point(token_index=11, time_index=33, score=0.9998375177383423)
# Point(token_index=11, time_index=34, score=0.9999696016311646)
# Point(token_index=11, time_index=35, score=0.9999157190322876)
# Point(token_index=11, time_index=36, score=0.9998534917831421)
# Point(token_index=11, time_index=37, score=0.9998533725738525)
# Point(token_index=11, time_index=38, score=0.9998522996902466)
# Point(token_index=11, time_index=39, score=0.9998563528060913)
# Point(token_index=11, time_index=40, score=0.9998273253440857)
# Point(token_index=11, time_index=41, score=0.9998553991317749)
# Point(token_index=11, time_index=42, score=0.9998563528060913)
# Point(token_index=11, time_index=43, score=0.9998346567153931)
# Point(token_index=11, time_index=44, score=0.9998500347137451)
# Point(token_index=11, time_index=45, score=0.9998283386230469)
# Point(token_index=11, time_index=46, score=0.9998397827148438)
# Point(token_index=11, time_index=47, score=0.9998441934585571)
# Point(token_index=11, time_index=48, score=0.9998206496238708)
# Point(token_index=11, time_index=49, score=0.9998401403427124)
# Point(token_index=11, time_index=50, score=0.9998347759246826)
# Point(token_index=11, time_index=51, score=0.9998341798782349)
# Point(token_index=11, time_index=52, score=0.9998347759246826)
# Point(token_index=11, time_index=53, score=0.9998434782028198)
# Point(token_index=12, time_index=54, score=0.9998440742492676)
# Point(token_index=12, time_index=55, score=0.9979362487792969)
# Point(token_index=12, time_index=56, score=0.9998451471328735)
# Point(token_index=12, time_index=57, score=0.9998658895492554)
# Point(token_index=12, time_index=58, score=0.9998689889907837)
# Point(token_index=13, time_index=59, score=0.998699426651001)
# Point(token_index=13, time_index=60, score=0.9998446702957153)
# Point(token_index=14, time_index=61, score=0.9996801614761353)
# Point(token_index=14, time_index=62, score=0.9997484087944031)
# Point(token_index=15, time_index=63, score=0.9977032542228699)
# Point(token_index=15, time_index=64, score=0.9762465357780457)
# Point(token_index=15, time_index=65, score=0.010565272532403469)
# Point(token_index=16, time_index=66, score=0.9989336133003235)
# Point(token_index=16, time_index=67, score=0.9998334646224976)
# Point(token_index=16, time_index=68, score=0.9998317956924438)
# Point(token_index=16, time_index=69, score=0.9998384714126587)
# Point(token_index=16, time_index=70, score=0.9998458623886108)
# Point(token_index=16, time_index=71, score=0.9998272061347961)
# Point(token_index=17, time_index=72, score=0.9997634291648865)
# Point(token_index=17, time_index=73, score=0.9998403787612915)
# Point(token_index=17, time_index=74, score=0.9998511075973511)
# Point(token_index=17, time_index=75, score=0.9998593330383301)
# Point(token_index=17, time_index=76, score=0.9999903440475464)
# Point(token_index=17, time_index=77, score=0.9999974966049194)
# Point(token_index=17, time_index=78, score=0.999997615814209)
# Point(token_index=17, time_index=79, score=0.9999974966049194)
# Point(token_index=17, time_index=80, score=0.9999964237213135)
# Point(token_index=17, time_index=81, score=0.9999932050704956)
# Point(token_index=17, time_index=82, score=0.9999619722366333)
# Point(token_index=17, time_index=83, score=0.9998669624328613)
# Point(token_index=17, time_index=84, score=0.9998748302459717)
# Point(token_index=17, time_index=85, score=0.9998791217803955)
# Point(token_index=18, time_index=86, score=0.9998233914375305)
# Point(token_index=18, time_index=87, score=0.9998792409896851)
# Point(token_index=19, time_index=88, score=0.9998493194580078)
# Point(token_index=19, time_index=89, score=0.9998592138290405)
# Point(token_index=19, time_index=90, score=0.9998890161514282)
# Point(token_index=19, time_index=91, score=0.9998730421066284)
# Point(token_index=19, time_index=92, score=0.9998657703399658)
# Point(token_index=20, time_index=93, score=0.999671220779419)
# Point(token_index=20, time_index=94, score=0.6701510548591614)
# Point(token_index=20, time_index=95, score=0.9941511750221252)
# Point(token_index=21, time_index=96, score=0.9983977675437927)
# Point(token_index=21, time_index=97, score=0.004194301087409258)
# Point(token_index=21, time_index=98, score=0.9998180270195007)
# Point(token_index=21, time_index=99, score=0.9998084902763367)
# Point(token_index=21, time_index=100, score=0.9998061060905457)
# Point(token_index=21, time_index=101, score=0.9998152852058411)
# Point(token_index=21, time_index=102, score=0.9998142123222351)
# Point(token_index=21, time_index=103, score=0.9999642372131348)
# Point(token_index=21, time_index=104, score=0.9999942779541016)
# Point(token_index=21, time_index=105, score=0.9998364448547363)
# Point(token_index=21, time_index=106, score=0.9999960660934448)
# Point(token_index=21, time_index=107, score=0.9999943971633911)
# Point(token_index=21, time_index=108, score=0.9999957084655762)
# Point(token_index=21, time_index=109, score=0.9998332262039185)
# Point(token_index=21, time_index=110, score=0.9999951124191284)
# Point(token_index=21, time_index=111, score=0.9998225569725037)
# Point(token_index=21, time_index=112, score=0.9998204112052917)
# Point(token_index=21, time_index=113, score=0.9998363256454468)
# Point(token_index=21, time_index=114, score=0.9998308420181274)
# Point(token_index=21, time_index=115, score=0.9998290538787842)
# Point(token_index=21, time_index=116, score=0.9998077750205994)
# Point(token_index=21, time_index=117, score=0.999830961227417)
# Point(token_index=21, time_index=118, score=0.999832272529602)
# Point(token_index=21, time_index=119, score=0.9998078942298889)
# Point(token_index=21, time_index=120, score=0.99981290102005)
# Point(token_index=21, time_index=121, score=0.9998062252998352)
# Point(token_index=21, time_index=122, score=0.9998230338096619)
# Point(token_index=21, time_index=123, score=0.9998225569725037)
# Point(token_index=21, time_index=124, score=0.9998109936714172)
# Point(token_index=21, time_index=125, score=0.9998051524162292)
# Point(token_index=21, time_index=126, score=0.9997933506965637)
# Point(token_index=21, time_index=127, score=0.9997949004173279)
# Point(token_index=21, time_index=128, score=0.9997593760490417)
# Point(token_index=21, time_index=129, score=0.9959695339202881)
# Point(token_index=21, time_index=130, score=0.9998030066490173)
# Point(token_index=21, time_index=131, score=0.9998173117637634)
# Point(token_index=21, time_index=132, score=0.9998181462287903)
# Point(token_index=21, time_index=133, score=0.9998101592063904)
# Point(token_index=21, time_index=134, score=0.9998133778572083)
# Point(token_index=21, time_index=135, score=0.999817430973053)
# Point(token_index=21, time_index=136, score=0.9998142123222351)
# Point(token_index=21, time_index=137, score=0.9998254179954529)
# Point(token_index=21, time_index=138, score=0.9998161196708679)
# Point(token_index=21, time_index=139, score=0.9998156428337097)
# Point(token_index=21, time_index=140, score=0.9998106360435486)
# Point(token_index=21, time_index=141, score=0.9997983574867249)
# Point(token_index=21, time_index=142, score=0.9997925162315369)
# Point(token_index=21, time_index=143, score=0.9997987151145935)
# Point(token_index=21, time_index=144, score=0.9998053908348083)
# Point(token_index=21, time_index=145, score=0.9998027682304382)
# Point(token_index=21, time_index=146, score=0.9998024106025696)
# Point(token_index=21, time_index=147, score=0.9998103976249695)
# Point(token_index=21, time_index=148, score=0.9998182654380798)
# Point(token_index=21, time_index=149, score=0.9997968077659607)
# Point(token_index=21, time_index=150, score=0.9997970461845398)
# Point(token_index=21, time_index=151, score=0.9998113512992859)
# Point(token_index=21, time_index=152, score=0.9998133778572083)
# Point(token_index=21, time_index=153, score=0.9998395442962646)
# Point(token_index=21, time_index=154, score=0.9998056292533875)
# Point(token_index=21, time_index=155, score=0.9997914433479309)
# Point(token_index=21, time_index=156, score=0.9997990727424622)
# Point(token_index=21, time_index=157, score=0.9997895359992981)
# Point(token_index=21, time_index=158, score=0.9959719777107239)
# Point(token_index=21, time_index=159, score=0.999822199344635)
# Point(token_index=21, time_index=160, score=0.9976876974105835)
# Point(token_index=21, time_index=161, score=0.9998076558113098)
# Point(token_index=21, time_index=162, score=0.9998053908348083)
# Point(token_index=21, time_index=163, score=0.9998144507408142)
# Point(token_index=21, time_index=164, score=0.9998024106025696)
# Point(token_index=21, time_index=165, score=0.9997978806495667)
# Point(token_index=21, time_index=166, score=0.9997959733009338)
# Point(token_index=21, time_index=167, score=0.9997873902320862)
# Point(token_index=21, time_index=168, score=0.9997897744178772)
# Point(token_index=21, time_index=169, score=0.9997531771659851)
# Point(token_index=21, time_index=170, score=0.9917552471160889)
# Point(token_index=21, time_index=171, score=0.9647011160850525)
# Point(token_index=21, time_index=172, score=0.9824134111404419)
# Point(token_index=21, time_index=173, score=0.9770423173904419)
# Point(token_index=21, time_index=174, score=0.9666063189506531)
# Point(token_index=21, time_index=175, score=0.9766666889190674)
# Point(token_index=21, time_index=176, score=0.986092746257782)
# Point(token_index=21, time_index=177, score=0.9893180727958679)
# Point(token_index=21, time_index=178, score=0.9911584258079529)
# Point(token_index=21, time_index=179, score=0.9906584024429321)
# Point(token_index=22, time_index=180, score=0.27634480595588684)
# Point(token_index=22, time_index=181, score=0.967517614364624)
# Point(token_index=22, time_index=182, score=0.9703036546707153)
# Point(token_index=22, time_index=183, score=0.9550346732139587)
# Point(token_index=23, time_index=184, score=0.1896420270204544)
# Point(token_index=23, time_index=185, score=0.9329321980476379)
# Point(token_index=23, time_index=186, score=0.9360199570655823)
# Point(token_index=23, time_index=187, score=0.9426918029785156)
# Point(token_index=23, time_index=188, score=0.9609861969947815)
# Point(token_index=23, time_index=189, score=0.9612394571304321)
# Point(token_index=23, time_index=190, score=0.9284676909446716)
# Point(token_index=23, time_index=191, score=0.4521158039569855)
# Point(token_index=24, time_index=192, score=0.8268582224845886)
# Point(token_index=24, time_index=193, score=0.674115002155304)
# Point(token_index=24, time_index=194, score=0.9832451343536377)
# Point(token_index=24, time_index=195, score=0.9998063445091248)
# Point(token_index=24, time_index=196, score=0.9998049139976501)
# Point(token_index=24, time_index=197, score=0.9998075366020203)
# Point(token_index=24, time_index=198, score=0.9998138546943665)
# Point(token_index=24, time_index=199, score=0.9998124241828918)
# Point(token_index=24, time_index=200, score=0.9998076558113098)
# Point(token_index=24, time_index=201, score=0.9998080134391785)
# Point(token_index=24, time_index=202, score=0.9998167157173157)
# Point(token_index=24, time_index=203, score=0.9998117089271545)
# Point(token_index=24, time_index=204, score=0.9998193383216858)
# Point(token_index=24, time_index=205, score=0.9998286962509155)
# Point(token_index=24, time_index=206, score=0.999815046787262)
# Point(token_index=24, time_index=207, score=0.9997957348823547)
# Point(token_index=24, time_index=208, score=0.9998177886009216)
# Point(token_index=24, time_index=209, score=0.9998100399971008)
# Point(token_index=24, time_index=210, score=0.9998044371604919)
# Point(token_index=24, time_index=211, score=0.9998064637184143)
# Point(token_index=24, time_index=212, score=0.999799907207489)
# Point(token_index=24, time_index=213, score=0.9998190999031067)
# Point(token_index=24, time_index=214, score=0.9998255372047424)
# Point(token_index=24, time_index=215, score=0.9998144507408142)
# Point(token_index=24, time_index=216, score=0.9998302459716797)
# Point(token_index=24, time_index=217, score=0.9998160004615784)
# Point(token_index=24, time_index=218, score=0.999804675579071)
# Point(token_index=24, time_index=219, score=0.9998148083686829)
# Point(token_index=24, time_index=220, score=0.9998262524604797)
# Point(token_index=24, time_index=221, score=0.9985706806182861)
# Point(token_index=24, time_index=222, score=0.9998052716255188)
# Point(token_index=24, time_index=223, score=0.9998183846473694)
# Point(token_index=24, time_index=224, score=0.9997943043708801)
# Point(token_index=24, time_index=225, score=0.9998236298561096)
# Point(token_index=24, time_index=226, score=0.9998006224632263)
# Point(token_index=24, time_index=227, score=0.9997997879981995)
# Point(token_index=24, time_index=228, score=0.9950000047683716)
# Point(token_index=24, time_index=229, score=0.9966327548027039)
# Point(token_index=24, time_index=230, score=0.9954915642738342)
# Point(token_index=24, time_index=231, score=0.9939369559288025)
# Point(token_index=24, time_index=232, score=0.9962241649627686)
# Point(token_index=24, time_index=233, score=0.9940085411071777)
# Point(token_index=24, time_index=234, score=0.9950965046882629)
# Point(token_index=24, time_index=235, score=0.9998062252998352)
# Point(token_index=24, time_index=236, score=0.9998175501823425)
# Point(token_index=24, time_index=237, score=0.9998195767402649)
# Point(token_index=24, time_index=238, score=0.9998100399971008)
# Point(token_index=24, time_index=239, score=0.9972420930862427)
# Point(token_index=24, time_index=240, score=0.9974601864814758)
# Point(token_index=24, time_index=241, score=0.9967177510261536)
# Point(token_index=24, time_index=242, score=0.9958330988883972)
# Point(token_index=24, time_index=243, score=0.9937878251075745)
# Point(token_index=24, time_index=244, score=0.9904554486274719)
# Point(token_index=24, time_index=245, score=0.9897626042366028)
# Point(token_index=24, time_index=246, score=0.9806597828865051)
# Point(token_index=24, time_index=247, score=0.9805240631103516)
# Point(token_index=24, time_index=248, score=0.9749898314476013)
# Point(token_index=24, time_index=249, score=0.9731661081314087)
# Point(token_index=24, time_index=250, score=0.9758327603340149)
# Point(token_index=24, time_index=251, score=0.9813278317451477)
# Point(token_index=24, time_index=252, score=0.9813321828842163)
# Point(token_index=24, time_index=253, score=0.9840437769889832)
# Point(token_index=24, time_index=254, score=0.9796120524406433)
# Point(token_index=24, time_index=255, score=0.9910764694213867)
# Point(token_index=24, time_index=256, score=0.9878786206245422)
# Point(token_index=24, time_index=257, score=0.9841041564941406)
# Point(token_index=24, time_index=258, score=0.9931443929672241)
# Point(token_index=24, time_index=259, score=0.9977582097053528)
# Point(token_index=24, time_index=260, score=0.9998231530189514)
# Point(token_index=24, time_index=261, score=0.9998144507408142)
# Point(token_index=24, time_index=262, score=0.9998186230659485)
# Point(token_index=24, time_index=263, score=0.9998107552528381)
# Point(token_index=24, time_index=264, score=0.9998195767402649)
# Point(token_index=24, time_index=265, score=0.9998140931129456)
# Point(token_index=24, time_index=266, score=0.9998204112052917)
# Point(token_index=24, time_index=267, score=0.9998230338096619)
# Point(token_index=24, time_index=268, score=0.9998235106468201)
# Point(token_index=24, time_index=269, score=0.9998189806938171)
# Point(token_index=24, time_index=270, score=0.9998260140419006)
# Point(token_index=24, time_index=271, score=0.9998231530189514)
# Point(token_index=24, time_index=272, score=0.9998284578323364)
# Point(token_index=24, time_index=273, score=0.999826967716217)
# Point(token_index=24, time_index=274, score=0.9998236298561096)
# Point(token_index=24, time_index=275, score=0.9998224377632141)
# Point(token_index=24, time_index=276, score=0.9998227953910828)
# Point(token_index=24, time_index=277, score=0.9998241066932678)
# Point(token_index=24, time_index=278, score=0.9998202919960022)
# Point(token_index=24, time_index=279, score=0.9998840093612671)
# Point(token_index=24, time_index=280, score=0.9998241066932678)
# Point(token_index=24, time_index=281, score=0.999803364276886)
# Point(token_index=24, time_index=282, score=0.9998226761817932)
# Point(token_index=24, time_index=283, score=0.9998230338096619)
# Point(token_index=24, time_index=284, score=0.9998165965080261)
# Point(token_index=24, time_index=285, score=0.9997939467430115)
# Point(token_index=24, time_index=286, score=0.9998044371604919)
# Point(token_index=24, time_index=287, score=0.9998080134391785)
# Point(token_index=24, time_index=288, score=0.9998224377632141)
# Point(token_index=24, time_index=289, score=0.9998351335525513)
# Point(token_index=24, time_index=290, score=0.9998394250869751)
# Point(token_index=24, time_index=291, score=0.9998515844345093)
# Point(token_index=24, time_index=292, score=0.9998335838317871)
# Point(token_index=25, time_index=293, score=0.9954572916030884)
# Point(token_index=25, time_index=294, score=0.9998120665550232)
# Point(token_index=25, time_index=295, score=0.9998538494110107)
# Point(token_index=25, time_index=296, score=0.9998672008514404)
# Point(token_index=26, time_index=297, score=0.998791515827179)
# Point(token_index=26, time_index=298, score=0.9998612403869629)
# Point(token_index=26, time_index=299, score=0.9998849630355835)
# Point(token_index=27, time_index=300, score=0.9982813596725464)
# Point(token_index=27, time_index=301, score=0.9998713731765747)
# Point(token_index=27, time_index=302, score=0.9998465776443481)
# Point(token_index=27, time_index=303, score=0.9997181296348572)
# Point(token_index=27, time_index=304, score=0.999819815158844)
# Point(token_index=27, time_index=305, score=0.9998268485069275)
# Point(token_index=27, time_index=306, score=0.9998040795326233)
# Point(token_index=28, time_index=307, score=0.9999176263809204)
# Point(token_index=28, time_index=308, score=0.9998562335968018)
# Point(token_index=28, time_index=309, score=0.9998552799224854)
# Point(token_index=28, time_index=310, score=0.999854564666748)
# Point(token_index=28, time_index=311, score=0.9998725652694702)
# Point(token_index=28, time_index=312, score=0.3082118034362793)
# Point(token_index=29, time_index=313, score=0.997160792350769)
# Point(token_index=29, time_index=314, score=0.999859094619751)
# Point(token_index=29, time_index=315, score=0.9998641014099121)
# Point(token_index=29, time_index=316, score=0.9998657703399658)
# Point(token_index=29, time_index=317, score=0.9717034697532654)
# Point(token_index=30, time_index=318, score=0.999777615070343)
# Point(token_index=31, time_index=319, score=0.9995095729827881)
# Point(token_index=31, time_index=320, score=0.9998422861099243)
# Point(token_index=31, time_index=321, score=0.9973030090332031)
# Point(token_index=31, time_index=322, score=0.002780878683552146)
# Point(token_index=32, time_index=323, score=0.9986886382102966)
# Point(token_index=32, time_index=324, score=0.9998414516448975)
# Point(token_index=33, time_index=325, score=0.9999290704727173)
# Point(token_index=33, time_index=326, score=0.9998613595962524)
# Point(token_index=34, time_index=327, score=0.9996799230575562)
# Point(token_index=34, time_index=328, score=0.9998406171798706)
# Point(token_index=34, time_index=329, score=0.9998540878295898)
# Point(token_index=34, time_index=330, score=0.9998745918273926)
# Point(token_index=35, time_index=331, score=0.9998286962509155)
# Point(token_index=35, time_index=332, score=0.9998598098754883)
# Point(token_index=35, time_index=333, score=0.9998668432235718)
# Point(token_index=36, time_index=334, score=0.9999289512634277)
# Point(token_index=36, time_index=335, score=0.9999043941497803)
# Point(token_index=36, time_index=336, score=0.9999109506607056)
# Point(token_index=36, time_index=337, score=0.9999088048934937)
# Point(token_index=37, time_index=338, score=0.9994382262229919)
# Point(token_index=37, time_index=339, score=0.06372316181659698)
# Point(token_index=37, time_index=340, score=0.9998670816421509)
# Point(token_index=37, time_index=341, score=0.9998680353164673)
# Point(token_index=37, time_index=342, score=0.9998563528060913)
# Point(token_index=38, time_index=343, score=0.9997943043708801)
# Point(token_index=38, time_index=344, score=0.9998468160629272)
# Point(token_index=38, time_index=345, score=0.9998551607131958)
# Point(token_index=38, time_index=346, score=0.9998518228530884)
# Point(token_index=39, time_index=347, score=0.9995304346084595)
# Point(token_index=39, time_index=348, score=0.9998757839202881)
# Point(token_index=39, time_index=349, score=0.9997974038124084)
# Point(token_index=40, time_index=350, score=0.9997913241386414)
# Point(token_index=40, time_index=351, score=0.9998500347137451)
# Point(token_index=40, time_index=352, score=0.9999957084655762)
# Point(token_index=40, time_index=353, score=0.9999986886978149)
# Point(token_index=40, time_index=354, score=0.999998927116394)
# Point(token_index=40, time_index=355, score=0.9999990463256836)
# Point(token_index=40, time_index=356, score=0.9999990463256836)
# Point(token_index=40, time_index=357, score=0.9999990463256836)
# Point(token_index=40, time_index=358, score=0.9999990463256836)
# Point(token_index=40, time_index=359, score=0.9999990463256836)
# Point(token_index=40, time_index=360, score=0.9999992847442627)
# Point(token_index=40, time_index=361, score=0.9999992847442627)
# Point(token_index=40, time_index=362, score=0.9999990463256836)
# Point(token_index=40, time_index=363, score=0.999840497970581)
# Point(token_index=40, time_index=364, score=0.9999990463256836)
# Point(token_index=40, time_index=365, score=0.9998394250869751)
# Point(token_index=40, time_index=366, score=0.999998927116394)
# Point(token_index=40, time_index=367, score=0.9998354911804199)
# Point(token_index=40, time_index=368, score=0.9999985694885254)
# Point(token_index=40, time_index=369, score=0.9998365640640259)
# Point(token_index=40, time_index=370, score=0.9999988079071045)
# Point(token_index=40, time_index=371, score=0.9999985694885254)
# Point(token_index=40, time_index=372, score=0.9999986886978149)
# Point(token_index=40, time_index=373, score=0.9999985694885254)
# Point(token_index=40, time_index=374, score=0.9999984502792358)
# Point(token_index=40, time_index=375, score=0.9999986886978149)
# Point(token_index=40, time_index=376, score=0.9999979734420776)
# Point(token_index=40, time_index=377, score=0.999997615814209)
# Point(token_index=40, time_index=378, score=0.9998887777328491)
# Point(token_index=40, time_index=379, score=0.999985933303833)
# Point(token_index=40, time_index=380, score=0.9999935626983643)
# Point(token_index=40, time_index=381, score=0.9999932050704956)
# Point(token_index=40, time_index=382, score=0.9998319149017334)
# Point(token_index=40, time_index=383, score=0.9998619556427002)
# Point(token_index=40, time_index=384, score=0.9998621940612793)
# Point(token_index=40, time_index=385, score=0.9998624324798584)
# Point(token_index=40, time_index=386, score=0.9998458623886108)
# Point(token_index=40, time_index=387, score=0.9998522996902466)
# Point(token_index=40, time_index=388, score=0.9998499155044556)
# Point(token_index=40, time_index=389, score=0.9998632669448853)
# Point(token_index=40, time_index=390, score=0.999855637550354)
# Point(token_index=40, time_index=391, score=0.999839186668396)
# Point(token_index=40, time_index=392, score=0.9998292922973633)
# Point(token_index=40, time_index=393, score=0.9998290538787842)
# Point(token_index=40, time_index=394, score=0.9998230338096619)
# Point(token_index=40, time_index=395, score=0.9998216032981873)
# Point(token_index=40, time_index=396, score=0.9998112320899963)
# Point(token_index=40, time_index=397, score=0.9998332262039185)
# Point(token_index=40, time_index=398, score=0.9998371601104736)
# Point(token_index=40, time_index=399, score=0.9998007416725159)
# Point(token_index=40, time_index=400, score=0.9998157620429993)
# Point(token_index=40, time_index=401, score=0.9953083395957947)
# Point(token_index=40, time_index=402, score=0.9972502589225769)
# Point(token_index=40, time_index=403, score=0.9932801127433777)
# Point(token_index=40, time_index=404, score=0.9978315234184265)
# Point(token_index=40, time_index=405, score=0.9995806813240051)
# Point(token_index=40, time_index=406, score=0.9998252987861633)
# Point(token_index=40, time_index=407, score=0.9998107552528381)
# Point(token_index=40, time_index=408, score=0.9998243451118469)
# Point(token_index=40, time_index=409, score=0.9998118281364441)
# Point(token_index=40, time_index=410, score=0.9998284578323364)
# Point(token_index=40, time_index=411, score=0.999788224697113)
# Point(token_index=40, time_index=412, score=0.37480267882347107)
# Point(token_index=40, time_index=413, score=0.9454654455184937)
# Point(token_index=40, time_index=414, score=0.936195433139801)
# Point(token_index=40, time_index=415, score=0.47181159257888794)
# Point(token_index=40, time_index=416, score=0.9751942157745361)
# Point(token_index=41, time_index=417, score=0.8756208419799805)
# Point(token_index=41, time_index=418, score=0.9371914863586426)
# Point(token_index=41, time_index=419, score=0.962029218673706)
# Point(token_index=42, time_index=420, score=0.5333244800567627)
# Point(token_index=42, time_index=421, score=0.44999948143959045)
# Point(token_index=43, time_index=422, score=0.8027587532997131)
# Point(token_index=44, time_index=423, score=0.9565147161483765)
# Point(token_index=44, time_index=424, score=0.9653792381286621)
# Point(token_index=45, time_index=425, score=0.9261131882667542)
# Point(token_index=45, time_index=426, score=0.9737305641174316)
# Point(token_index=46, time_index=427, score=0.9730826616287231)
# Point(token_index=46, time_index=428, score=0.9997881054878235)
# Point(token_index=47, time_index=429, score=0.9698585271835327)
# Point(token_index=47, time_index=430, score=0.9443166255950928)
# Point(token_index=48, time_index=431, score=0.8745430111885071)
# Point(token_index=48, time_index=432, score=0.997715950012207)
# Point(token_index=49, time_index=433, score=0.9509198665618896)
# Point(token_index=50, time_index=434, score=0.9383992552757263)
# Point(token_index=50, time_index=435, score=0.9774709939956665)
# Point(token_index=50, time_index=436, score=0.009229196235537529)
# Point(token_index=51, time_index=437, score=0.7543888688087463)
# Point(token_index=51, time_index=438, score=0.0005379369831643999)
# Point(token_index=51, time_index=439, score=0.001494414871558547)
# Point(token_index=51, time_index=440, score=0.0009532402036711574)
# Point(token_index=51, time_index=441, score=0.0006626680842600763)
# Point(token_index=51, time_index=442, score=0.12890300154685974)
# Point(token_index=51, time_index=443, score=0.9998155236244202)
# Point(token_index=52, time_index=444, score=0.9998612403869629)
# Point(token_index=52, time_index=445, score=0.9998239874839783)
# Point(token_index=52, time_index=446, score=0.9998239874839783)
# Point(token_index=52, time_index=447, score=0.9998326301574707)
# Point(token_index=52, time_index=448, score=0.9998194575309753)
# Point(token_index=53, time_index=449, score=0.9991905093193054)
# Point(token_index=53, time_index=450, score=0.9998014569282532)
# Point(token_index=53, time_index=451, score=0.9998393058776855)
# Point(token_index=53, time_index=452, score=0.9998576641082764)
# Point(token_index=53, time_index=453, score=0.9998557567596436)
# Point(token_index=53, time_index=454, score=0.9998505115509033)
# Point(token_index=54, time_index=455, score=0.9975715279579163)
# Point(token_index=54, time_index=456, score=0.9998515844345093)
# Point(token_index=54, time_index=457, score=0.9996852874755859)
# Point(token_index=55, time_index=458, score=0.9989151954650879)
# Point(token_index=55, time_index=459, score=0.9998045563697815)
# Point(token_index=55, time_index=460, score=0.9943384528160095)
# Point(token_index=56, time_index=461, score=0.9808334112167358)
# Point(token_index=56, time_index=462, score=0.9893478155136108)
# Point(token_index=56, time_index=463, score=0.9357814788818359)
# Point(token_index=57, time_index=464, score=0.997936487197876)
# Point(token_index=57, time_index=465, score=0.27987903356552124)
# Point(token_index=57, time_index=466, score=0.999825656414032)
# Point(token_index=58, time_index=467, score=0.9914848208427429)
# Point(token_index=59, time_index=468, score=0.995553195476532)
# Point(token_index=59, time_index=469, score=0.05425899848341942)
# Point(token_index=60, time_index=470, score=0.9809401631355286)
# Point(token_index=61, time_index=471, score=0.9982219338417053)
# Point(token_index=61, time_index=472, score=0.999881386756897)
# Point(token_index=62, time_index=473, score=0.9983922839164734)
# Point(token_index=62, time_index=474, score=0.9998365640640259)
# Point(token_index=63, time_index=475, score=0.9964730143547058)
# Point(token_index=63, time_index=476, score=0.05995069444179535)
# Point(token_index=64, time_index=477, score=0.9815581440925598)
# Point(token_index=64, time_index=478, score=0.9956438541412354)
# Point(token_index=64, time_index=479, score=0.9983018636703491)
# Point(token_index=64, time_index=480, score=0.9998527765274048)
# Point(token_index=65, time_index=481, score=0.9855358600616455)
# Point(token_index=65, time_index=482, score=0.9981412887573242)
# Point(token_index=66, time_index=483, score=0.9716256856918335)
# Point(token_index=66, time_index=484, score=0.21733134984970093)
# Point(token_index=67, time_index=485, score=0.9824936985969543)
# Point(token_index=67, time_index=486, score=0.9997803568840027)
# Point(token_index=67, time_index=487, score=0.9997738003730774)
# Point(token_index=68, time_index=488, score=0.9987156391143799)
# Point(token_index=68, time_index=489, score=0.9998575448989868)
# Point(token_index=68, time_index=490, score=0.9998513460159302)
# Point(token_index=69, time_index=491, score=0.9996598958969116)
# Point(token_index=69, time_index=492, score=0.9998648166656494)
# Point(token_index=69, time_index=493, score=0.9998840093612671)
# Point(token_index=69, time_index=494, score=0.9998699426651001)
# Point(token_index=70, time_index=495, score=0.9955145716667175)
# Point(token_index=71, time_index=496, score=0.9995549321174622)
# Point(token_index=71, time_index=497, score=0.9998478889465332)
# Point(token_index=71, time_index=498, score=0.9998470544815063)
# Point(token_index=71, time_index=499, score=0.9998341798782349)
# Point(token_index=72, time_index=500, score=0.9998056292533875)
# Point(token_index=72, time_index=501, score=0.9998134970664978)
# Point(token_index=72, time_index=502, score=0.9998397827148438)
# Point(token_index=72, time_index=503, score=0.9992615580558777)
# Point(token_index=73, time_index=504, score=0.9987180233001709)
# Point(token_index=73, time_index=505, score=0.9949724674224854)
# Point(token_index=73, time_index=506, score=0.9877337217330933)
# Point(token_index=74, time_index=507, score=0.997923731803894)
# Point(token_index=74, time_index=508, score=0.9998444318771362)
# Point(token_index=74, time_index=509, score=0.9998325109481812)
# Point(token_index=74, time_index=510, score=0.9998236298561096)
# Point(token_index=74, time_index=511, score=0.9998601675033569)
# Point(token_index=75, time_index=512, score=0.9874936938285828)
# Point(token_index=76, time_index=513, score=0.9877188205718994)
# Point(token_index=76, time_index=514, score=0.2397516667842865)
# Point(token_index=77, time_index=515, score=0.8414452075958252)
# Point(token_index=78, time_index=516, score=0.8445284962654114)
# Point(token_index=78, time_index=517, score=0.20284487307071686)
# Point(token_index=78, time_index=518, score=0.9847988486289978)
# Point(token_index=78, time_index=519, score=0.9945061802864075)
# Point(token_index=79, time_index=520, score=0.8832395076751709)
# Point(token_index=80, time_index=521, score=0.9270175695419312)
# Point(token_index=80, time_index=522, score=0.6914064288139343)
# Point(token_index=81, time_index=523, score=0.9799071550369263)
# Point(token_index=81, time_index=524, score=0.999815046787262)
# Point(token_index=81, time_index=525, score=0.9998618364334106)
# Point(token_index=82, time_index=526, score=0.9997199177742004)
# Point(token_index=82, time_index=527, score=0.9998266100883484)
# Point(token_index=82, time_index=528, score=0.9998292922973633)
# Point(token_index=82, time_index=529, score=0.999853253364563)
# Point(token_index=83, time_index=530, score=0.9981697797775269)
# Point(token_index=83, time_index=531, score=0.9998372793197632)
# Point(token_index=84, time_index=532, score=0.9963147044181824)
# Point(token_index=84, time_index=533, score=0.9998323917388916)
# Point(token_index=84, time_index=534, score=0.9998270869255066)
# Point(token_index=85, time_index=535, score=0.996100664138794)
# Point(token_index=85, time_index=536, score=0.9998452663421631)
# Point(token_index=86, time_index=537, score=0.9991357922554016)
# Point(token_index=87, time_index=538, score=0.9811679124832153)
# Point(token_index=87, time_index=539, score=0.019984468817710876)
# Point(token_index=87, time_index=540, score=0.7835950255393982)
# Point(token_index=87, time_index=541, score=0.9504764080047607)
# Point(token_index=87, time_index=542, score=0.8422043323516846)
# Point(token_index=87, time_index=543, score=0.32876643538475037)
# Point(token_index=88, time_index=544, score=0.9950354099273682)
# Point(token_index=88, time_index=545, score=0.9998617172241211)
# Point(token_index=88, time_index=546, score=0.9998551607131958)
# Point(token_index=88, time_index=547, score=0.9998568296432495)
# Point(token_index=88, time_index=548, score=0.9998416900634766)
# Point(token_index=88, time_index=549, score=0.9998041987419128)
# Point(token_index=88, time_index=550, score=0.999811589717865)
# Point(token_index=88, time_index=551, score=0.9998466968536377)
# Point(token_index=89, time_index=552, score=0.9987828135490417)
# Point(token_index=90, time_index=553, score=0.9971621632575989)
# Point(token_index=90, time_index=554, score=0.8998903036117554)
# Point(token_index=91, time_index=555, score=0.9982622265815735)
# Point(token_index=91, time_index=556, score=0.9998157620429993)
# Point(token_index=91, time_index=557, score=0.9997895359992981)
# Point(token_index=91, time_index=558, score=0.9998706579208374)
# Point(token_index=92, time_index=559, score=0.9986318945884705)
# Point(token_index=93, time_index=560, score=0.9997345805168152)
# Point(token_index=93, time_index=561, score=0.9998770952224731)
# Point(token_index=94, time_index=562, score=0.9995810389518738)
# Point(token_index=94, time_index=563, score=0.9998307228088379)
# Point(token_index=94, time_index=564, score=0.9998252987861633)
# Point(token_index=95, time_index=565, score=0.9978693723678589)
# Point(token_index=95, time_index=566, score=0.9998356103897095)
# Point(token_index=96, time_index=567, score=0.9990009665489197)
# Point(token_index=96, time_index=568, score=0.16193190217018127)
# Point(token_index=97, time_index=569, score=0.995381236076355)
# Point(token_index=97, time_index=570, score=0.999830961227417)
# Point(token_index=97, time_index=571, score=0.999872088432312)
# Point(token_index=98, time_index=572, score=0.9957371950149536)
# Point(token_index=99, time_index=573, score=0.996117353439331)
# Point(token_index=99, time_index=574, score=0.562109649181366)
# Point(token_index=100, time_index=575, score=0.9989722967147827)
# Point(token_index=100, time_index=576, score=0.999862551689148)
# Point(token_index=100, time_index=577, score=0.9999876022338867)
# Point(token_index=100, time_index=578, score=0.9999933242797852)
# Point(token_index=100, time_index=579, score=0.9999240636825562)
# Point(token_index=101, time_index=580, score=0.999875545501709)
# Point(token_index=101, time_index=581, score=0.9998632669448853)
# Point(token_index=101, time_index=582, score=0.9999839067459106)
# Point(token_index=101, time_index=583, score=0.9999972581863403)
# Point(token_index=101, time_index=584, score=0.9999980926513672)
# Point(token_index=101, time_index=585, score=0.9999980926513672)
# Point(token_index=101, time_index=586, score=0.9999979734420776)
# Point(token_index=101, time_index=587, score=0.9999933242797852)
# Point(token_index=101, time_index=588, score=0.9998584985733032)
# Point(token_index=102, time_index=589, score=0.9999656677246094)
# Point(token_index=102, time_index=590, score=0.9998513460159302)
# Point(token_index=103, time_index=591, score=0.9997766613960266)
# Point(token_index=103, time_index=592, score=0.05302940309047699)
# Point(token_index=104, time_index=593, score=0.9998559951782227)
# Point(token_index=104, time_index=594, score=0.04550822824239731)
# Point(token_index=105, time_index=595, score=0.9990129470825195)
# Point(token_index=105, time_index=596, score=0.9998319149017334)
# Point(token_index=106, time_index=597, score=0.9985265731811523)
# Point(token_index=106, time_index=598, score=0.9998539686203003)
# Point(token_index=107, time_index=599, score=0.9954467415809631)
# Point(token_index=107, time_index=600, score=0.9998297691345215)
# Point(token_index=107, time_index=601, score=0.9998571872711182)
# Point(token_index=108, time_index=602, score=0.9986538887023926)
# Point(token_index=108, time_index=603, score=0.9998401403427124)
# Point(token_index=109, time_index=604, score=0.9990757703781128)
# Point(token_index=109, time_index=605, score=0.9998680353164673)
# Point(token_index=109, time_index=606, score=0.999879002571106)
# Point(token_index=110, time_index=607, score=0.9978939890861511)
# Point(token_index=110, time_index=608, score=0.9998489618301392)
# Point(token_index=111, time_index=609, score=0.6987162232398987)

# %%
forced_alignment_utils.plot_trellis_with_path(trellis, path)
plt.show()

# %%
segments = forced_alignment_utils.merge_repeats(path, transcript)
for seg in segments:
    print(seg)
# Out:
# T	(0.99): [    2,     6)
# E	(1.00): [    6,     8)
# M	(1.00): [    8,    10)
# P	(1.00): [   10,    12)
# E	(1.00): [   12,    14)
# R	(1.00): [   14,    17)
# A	(1.00): [   17,    19)
# T	(1.00): [   19,    24)
# U	(0.72): [   24,    26)
# R	(1.00): [   26,    27)
# E	(0.66): [   27,    30)
# |	(0.98): [   30,    54)
# W	(1.00): [   54,    59)
# E	(1.00): [   59,    61)
# N	(1.00): [   61,    63)
# T	(0.66): [   63,    66)
# |	(1.00): [   66,    72)
# D	(1.00): [   72,    86)
# O	(1.00): [   86,    88)
# W	(1.00): [   88,    93)
# N	(0.89): [   93,    96)
# |	(0.99): [   96,   180)
# U	(0.79): [  180,   184)
# M	(0.79): [  184,   192)
# |	(0.99): [  192,   293)
# F	(1.00): [  293,   297)
# I	(1.00): [  297,   300)
# F	(1.00): [  300,   307)
# T	(0.88): [  307,   313)
# E	(0.99): [  313,   318)
# E	(1.00): [  318,   319)
# N	(0.75): [  319,   323)
# |	(1.00): [  323,   325)
# D	(1.00): [  325,   327)
# E	(1.00): [  327,   331)
# G	(1.00): [  331,   334)
# R	(1.00): [  334,   338)
# E	(0.81): [  338,   343)
# E	(1.00): [  343,   347)
# S	(1.00): [  347,   350)
# |	(0.98): [  350,   417)
# C	(0.92): [  417,   420)
# A	(0.49): [  420,   422)
# U	(0.80): [  422,   423)
# S	(0.96): [  423,   425)
# E	(0.95): [  425,   427)
# |	(0.99): [  427,   429)
# F	(0.96): [  429,   431)
# R	(0.94): [  431,   433)
# O	(0.95): [  433,   434)
# M	(0.64): [  434,   437)
# |	(0.27): [  437,   444)
# S	(1.00): [  444,   449)
# T	(1.00): [  449,   455)
# A	(1.00): [  455,   458)
# R	(1.00): [  458,   461)
# T	(0.97): [  461,   464)
# |	(0.76): [  464,   467)
# I	(0.99): [  467,   468)
# T	(0.52): [  468,   470)
# |	(0.98): [  470,   471)
# W	(1.00): [  471,   473)
# A	(1.00): [  473,   475)
# S	(0.53): [  475,   477)
# |	(0.99): [  477,   481)
# A	(0.99): [  481,   483)
# T	(0.59): [  483,   485)
# |	(0.99): [  485,   488)
# T	(1.00): [  488,   491)
# W	(1.00): [  491,   495)
# E	(1.00): [  495,   496)
# N	(1.00): [  496,   500)
# T	(1.00): [  500,   504)
# Y	(0.99): [  504,   507)
# |	(1.00): [  507,   512)
# A	(0.99): [  512,   513)
# N	(0.61): [  513,   515)
# D	(0.84): [  515,   516)
# |	(0.76): [  516,   520)
# A	(0.88): [  520,   521)
# T	(0.81): [  521,   523)
# |	(0.99): [  523,   526)
# F	(1.00): [  526,   530)
# I	(1.00): [  530,   532)
# N	(1.00): [  532,   535)
# I	(1.00): [  535,   537)
# S	(1.00): [  537,   538)
# H	(0.65): [  538,   544)
# |	(1.00): [  544,   552)
# I	(1.00): [  552,   553)
# T	(0.95): [  553,   555)
# |	(1.00): [  555,   559)
# E	(1.00): [  559,   560)
# N	(1.00): [  560,   562)
# D	(1.00): [  562,   565)
# E	(1.00): [  565,   567)
# D	(0.58): [  567,   569)
# |	(1.00): [  569,   572)
# A	(1.00): [  572,   573)
# T	(0.78): [  573,   575)
# |	(1.00): [  575,   580)
# F	(1.00): [  580,   589)
# I	(1.00): [  589,   591)
# V	(0.53): [  591,   593)
# E	(0.52): [  593,   595)
# |	(1.00): [  595,   597)
# D	(1.00): [  597,   599)
# E	(1.00): [  599,   602)
# G	(1.00): [  602,   604)
# R	(1.00): [  604,   607)
# E	(1.00): [  607,   609)
# E	(0.70): [  609,   610)

# %%
forced_alignment_utils.plot_trellis_with_segments(path, trellis, segments, transcript)
plt.show()

# %%
word_segments = forced_alignment_utils.merge_words(segments)
for word in word_segments:
    print(word)
# Out:
# TEMPERATURE	(0.94): [    2,    30)
# WENT	(0.91): [   54,    66)
# DOWN	(0.99): [   72,    96)
# UM	(0.79): [  180,   192)
# FIFTEEN	(0.94): [  293,   323)
# DEGREES	(0.96): [  325,   350)
# CAUSE	(0.84): [  417,   427)
# FROM	(0.83): [  429,   437)
# START	(0.99): [  444,   464)
# IT	(0.68): [  467,   470)
# WAS	(0.84): [  471,   477)
# AT	(0.79): [  481,   485)
# TWENTY	(1.00): [  488,   507)
# AND	(0.76): [  512,   516)
# AT	(0.83): [  520,   523)
# FINISH	(0.88): [  526,   544)
# IT	(0.97): [  552,   555)
# ENDED	(0.92): [  559,   569)
# AT	(0.85): [  572,   575)
# FIVE	(0.87): [  580,   595)
# DEGREE	(0.98): [  597,   610)

# %%
forced_alignment_utils.plot_alignments(
    bundle,
    trellis,
    segments,
    word_segments,
    waveform[0],
)
plt.show()
print("num words: " + str(len(word_segments)))
# Out:
# num words: 21

# %%
# A trick to embed the resulting audio to the generated file.
# `IPython.display.Audio` has to be the last call in a cell,
# and there should be only one call par cell.
from scipy.io.wavfile import write

def write_segment(path, i):
    ratio = waveform.size(1) / (trellis.size(0) - 1)
    word = word_segments[i]
    x0 = int(ratio * word.start)
    x1 = int(ratio * word.end)
    print(f"{word.label} ({word.score:.2f}): {x0 / bundle.sample_rate:.3f} - {x1 / bundle.sample_rate:.3f} sec")
    segment = waveform[:, x0:x1]
    torchaudio.save(os.path.join(path, f"segment{i}.wav"), segment, bundle.sample_rate)

# Generate the audio for each segment

for i in range(len(word_segments)):
    segm = write_segment(new_dir, i)

avg_confidence = sum([word.score for word in word_segments]) / len(word_segments)
print(f"Average confidence score across words in ground truth transcript file: {avg_confidence:.3f}")
# Out:
# TEMPERATURE (0.94): 0.040 - 0.601 sec
# WENT (0.91): 1.082 - 1.322 sec
# DOWN (0.99): 1.442 - 1.923 sec
# UM (0.79): 3.606 - 3.847 sec
# FIFTEEN (0.94): 5.870 - 6.471 sec
# DEGREES (0.96): 6.511 - 7.012 sec
# CAUSE (0.84): 8.355 - 8.555 sec
# FROM (0.83): 8.595 - 8.755 sec
# START (0.99): 8.896 - 9.296 sec
# IT (0.68): 9.356 - 9.416 sec
# WAS (0.84): 9.437 - 9.557 sec
# AT (0.79): 9.637 - 9.717 sec
# TWENTY (1.00): 9.777 - 10.158 sec
# AND (0.76): 10.258 - 10.338 sec
# AT (0.83): 10.418 - 10.478 sec
# FINISH (0.88): 10.538 - 10.899 sec
# IT (0.97): 11.059 - 11.119 sec
# ENDED (0.92): 11.200 - 11.400 sec
# AT (0.85): 11.460 - 11.520 sec
# FIVE (0.87): 11.620 - 11.921 sec
# DEGREE (0.98): 11.961 - 12.221 sec
# Average confidence score across words in ground truth transcript file: 0.885
